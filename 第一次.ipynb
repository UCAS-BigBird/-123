# %% [markdown]
# <a href="https://colab.research.google.com/github/UCAS-BigBird/-123/blob/master/%E7%AC%AC%E4%B8%80%E6%AC%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
X_train = pd.read_csv("xtrain.csv", header=None)
Y_train = pd.read_csv("ytrain.csv", header=None)
X_test = pd.read_csv("xtest.csv", header=None)
Y_test = pd.read_csv("ytest.csv", header=None)

# %%
X_train.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.150365 -0.390642 -1.128550 -0.958764  0.310984 -0.595995 -0.802596
# 1 -0.937990  0.680514 -0.948201 -0.821525 -0.609636 -0.909867 -0.660669
# 2  0.574121 -1.033336  0.513941  0.408586 -0.106161 -0.363019 -0.417990
# 3 -0.547220 -0.316022 -0.577622 -0.566615  0.586662 -0.649331 -0.805298
# 4 -0.527398  0.791240 -0.561563 -0.523571 -1.051446 -1.017532 -0.905149
#
#          7         8         9     ...           20        21        22  \
# 0 -0.802490  0.294539  0.094251    ...    -1.043176  0.213533 -1.036045
# 1 -0.898716  0.754935 -0.425471    ...    -0.715654  1.066842 -0.689922
# 2 -0.088446 -0.271820 -0.575221    ...     0.297615 -0.977818  0.262137
# 3 -0.500065  0.331078  0.540567    ...    -0.701325 -0.757927 -0.735737
# 4 -0.935806 -0.969721 -0.426939    ...    -0.427026  1.058637 -0.422423
#
#          23        24        25        26        27        28        29
# ...
